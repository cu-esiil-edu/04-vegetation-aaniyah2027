# %%
pip install osmnx geopandas matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import osmnx as ox
import matplotlib.pyplot as plt

# Location name
place_name = "Gila River Indian Community, Arizona, USA"

# Download boundary from OpenStreetMap
gdf = ox.geocode_to_gdf(place_name)

# Plot the boundary
fig, ax = plt.subplots(figsize=(10, 10))
gdf.plot(ax=ax, edgecolor='black', facecolor='lightblue')

plt.title("Gila River Indian Community")
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.show()

# %%
# %store gdf
# Out:
# Stored 'gdf' (GeoDataFrame)
