# %%
import osmnx as ox
import geopandas as gpd
import hvplot.pandas
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#   > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
# ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1011'>
#   <div id="a74d3ed6-770d-4dd7-bad2-b23b42c6c589" data-root-id="p1011" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
# Look for GRIC with OSM
place = "Fort Valley State University, Georgia, USA"

fvsu_boundary = ox.geocode_to_gdf(place)

fvsu_boundary
# Out:
#                                             geometry  bbox_west  bbox_south  \
# 0  POLYGON ((-83.9022 32.53398, -83.90218 32.5337... -83.902203   32.525196
#
#    bbox_east  bbox_north   place_id osm_type     osm_id        lat        lon  \
# 0 -83.882058   32.542159  342961875      way  722635040  32.533663 -83.895046
#
#      class        type  place_rank  importance addresstype  \
# 0  amenity  university          30    0.406736     amenity
#
#                            name  \
# 0  Fort Valley State University
#
#                                         display_name
# 0  Fort Valley State University, 1005, State Univ...

# %%
fvsu_boundary.plot()
# Out:
# <Axes: >

# %%
# %store fvsu_boundary
# Out:
# Stored 'fvsu_boundary' (GeoDataFrame)
